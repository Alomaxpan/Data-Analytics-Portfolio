# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.listdir()
# Out:
# ['.config', 'ecommerce_customer_behavior.csv', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv('ecommerce_customer_behavior.csv')
df.head()
# Out:
#   Customer_ID  Age  Gender   Country      City Device_Type  Browser  \
# 0    CUST1000   56    Male    Canada    London      Mobile  Firefox
# 1    CUST1001   46  Female        UK    Mumbai      Tablet   Safari
# 2    CUST1002   32    Male  Pakistan  New York      Tablet     Edge
# 3    CUST1003   60   Other    Canada   Toronto      Tablet     Edge
# 4    CUST1004   25    Male     India    Lahore     Desktop  Firefox
#
#    Session_Duration  Pages_Viewed  Clicked_Ad Product_Category  \
# 0             28.45             8           1             Home
# 1              1.81             1           0            Books
# 2              5.81             2           0             Home
# 3             16.26            18           1            Books
# 4              2.64            15           1         Clothing
#
#    Purchase_Amount    Payment_Method  Discount_Applied  Delivery_Time_Days  \
# 0           436.72  Cash on Delivery                 1                   1
# 1            40.27       Credit Card                 1                  13
# 2           427.86       Credit Card                 1                   3
# 3           391.91  Cash on Delivery                 0                   3
# 4            56.24  Cash on Delivery                 0                  11
#
#    Return  Customer_Satisfaction Membership_Level  Loyalty_Points  \
# 0       1                      5             Gold              15
# 1       1                      1              NaN             110
# 2       1                      1              NaN             871
# 3       0                      5              NaN             712
# 4       1                      4             Gold             106
#
#    Referral_Used
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            1000 non-null   object
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Country                1000 non-null   object
#  4   City                   1000 non-null   object
#  5   Device_Type            1000 non-null   object
#  6   Browser                1000 non-null   object
#  7   Session_Duration       1000 non-null   float64
#  8   Pages_Viewed           1000 non-null   int64
#  9   Clicked_Ad             1000 non-null   int64
#  10  Product_Category       1000 non-null   object
#  11  Purchase_Amount        1000 non-null   float64
#  12  Payment_Method         1000 non-null   object
#  13  Discount_Applied       1000 non-null   int64
#  14  Delivery_Time_Days     1000 non-null   int64
#  15  Return                 1000 non-null   int64
#  16  Customer_Satisfaction  1000 non-null   int64
#  17  Membership_Level       754 non-null    object
#  18  Loyalty_Points         1000 non-null   int64
#  19  Referral_Used          1000 non-null   int64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#                Age  Session_Duration  Pages_Viewed   Clicked_Ad  \
# count  1000.000000       1000.000000   1000.000000  1000.000000
# mean     40.986000         29.903300      9.933000     0.505000
# std      13.497852         16.882898      5.519327     0.500225
# min      18.000000          1.000000      1.000000     0.000000
# 25%      29.000000         15.172500      5.000000     0.000000
# 50%      42.000000         29.870000     10.000000     1.000000
# 75%      52.000000         44.125000     15.000000     1.000000
# max      64.000000         59.870000     19.000000     1.000000
#
#        Purchase_Amount  Discount_Applied  Delivery_Time_Days       Return  \
# count      1000.000000       1000.000000         1000.000000  1000.000000
# mean        259.052120          0.522000            7.518000     0.513000
# std         144.030604          0.499766            3.989435     0.500081
# min           5.900000          0.000000            1.000000     0.000000
# 25%         135.922500          0.000000            4.000000     0.000000
# 50%         265.980000          1.000000            7.000000     1.000000
# 75%         386.727500          1.000000           11.000000     1.000000
# max         499.870000          1.000000           14.000000     1.000000
#
#        Customer_Satisfaction  Loyalty_Points  Referral_Used
# count            1000.000000     1000.000000    1000.000000
# mean                2.970000      519.390000       0.486000
# std                 1.399664      290.718553       0.500054
# min                 1.000000        0.000000       0.000000
# 25%                 2.000000      267.000000       0.000000
# 50%                 3.000000      515.500000       0.000000
# 75%                 4.000000      785.000000       1.000000
# max                 5.000000      999.000000       1.000000

# %%
df.isnull().sum()
# Out:
# Customer_ID                0
# Age                        0
# Gender                     0
# Country                    0
# City                       0
# Device_Type                0
# Browser                    0
# Session_Duration           0
# Pages_Viewed               0
# Clicked_Ad                 0
# Product_Category           0
# Purchase_Amount            0
# Payment_Method             0
# Discount_Applied           0
# Delivery_Time_Days         0
# Return                     0
# Customer_Satisfaction      0
# Membership_Level         246
# Loyalty_Points             0
# Referral_Used              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Country', 'City', 'Device_Type',
#        'Browser', 'Session_Duration', 'Pages_Viewed', 'Clicked_Ad',
#        'Product_Category', 'Purchase_Amount', 'Payment_Method',
#        'Discount_Applied', 'Delivery_Time_Days', 'Return',
#        'Customer_Satisfaction', 'Membership_Level', 'Loyalty_Points',
#        'Referral_Used'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            1000 non-null   object
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Country                1000 non-null   object
#  4   City                   1000 non-null   object
#  5   Device_Type            1000 non-null   object
#  6   Browser                1000 non-null   object
#  7   Session_Duration       1000 non-null   float64
#  8   Pages_Viewed           1000 non-null   int64
#  9   Clicked_Ad             1000 non-null   int64
#  10  Product_Category       1000 non-null   object
#  11  Purchase_Amount        1000 non-null   float64
#  12  Payment_Method         1000 non-null   object
#  13  Discount_Applied       1000 non-null   int64
#  14  Delivery_Time_Days     1000 non-null   int64
#  15  Return                 1000 non-null   int64
#  16  Customer_Satisfaction  1000 non-null   int64
#  17  Membership_Level       754 non-null    object
#  18  Loyalty_Points         1000 non-null   int64
#  19  Referral_Used          1000 non-null   int64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 156.4+ KB

# %%
total_revenue = df["Purchase_Amount"].sum()

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 259052.12

# %%
avg_spend = df["Purchase_Amount"].mean()

print("Average Customer Spend:", avg_spend)
# Out:
# Average Customer Spend: 259.05212

# %%
category_sales = df.groupby("Product_Category")["Purchase_Amount"].sum()

category_sales.sort_values(ascending=False)
# Out:
# Product_Category
# Clothing       58407.27
# Electronics    57616.65
# Home           49482.66
# Beauty         47457.58
# Books          46087.96
# Name: Purchase_Amount, dtype: float64

# %%
import matplotlib.pyplot as plt

category_sales.sort_values(ascending=False).plot(kind="bar")

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.show()

# %%
membership_spend = df.groupby("Membership_Level")["Purchase_Amount"].mean()

membership_spend
# Out:
# Membership_Level
# Gold        265.340119
# Platinum    259.508258
# Silver      265.414430
# Name: Purchase_Amount, dtype: float64

# %%
device_usage = df["Device_Type"].value_counts()

device_usage.plot(kind="bar")

plt.title("Customer Device Usage")
plt.show()

# %%
df["Membership_Level"].value_counts()
# Out:
# Membership_Level
# Platinum    264
# Gold        253
# Silver      237
# Name: count, dtype: int64

# %%
membership_spend = df.groupby("Membership_Level")["Purchase_Amount"].mean()

membership_spend
# Out:
# Membership_Level
# Gold        265.340119
# Platinum    259.508258
# Silver      265.414430
# Name: Purchase_Amount, dtype: float64

# %%
import matplotlib.pyplot as plt

membership_spend.plot(kind="bar")

plt.title("Average Purchase Amount by Membership Level")
plt.xlabel("Membership Level")
plt.ylabel("Average Purchase Amount")

plt.show()

# %%
top_customers = df.sort_values("Purchase_Amount", ascending=False)

top_customers[["Customer_ID","Membership_Level","Purchase_Amount"]].head(10)
# Out:
#     Customer_ID Membership_Level  Purchase_Amount
# 746    CUST1746         Platinum           499.87
# 726    CUST1726           Silver           499.12
# 382    CUST1382           Silver           498.80
# 248    CUST1248              NaN           498.17
# 123    CUST1123             Gold           496.42
# 67     CUST1067             Gold           496.34
# 735    CUST1735             Gold           495.99
# 791    CUST1791             Gold           495.57
# 973    CUST1973             Gold           495.54
# 594    CUST1594         Platinum           495.40

# %%
discount_analysis = df.groupby("Discount_Applied")["Purchase_Amount"].mean()

discount_analysis
# Out:
# Discount_Applied
# 0    258.368870
# 1    259.677778
# Name: Purchase_Amount, dtype: float64

# %%
discount_analysis.plot(kind="bar")

plt.title("Impact of Discount on Purchase Amount")
plt.xlabel("Discount Applied")
plt.ylabel("Average Purchase Amount")

plt.show()

# %%
satisfaction_spend = df.groupby("Customer_Satisfaction")["Purchase_Amount"].mean()

satisfaction_spend
# Out:
# Customer_Satisfaction
# 1    244.648030
# 2    262.698465
# 3    270.796597
# 4    248.948009
# 5    269.629514
# Name: Purchase_Amount, dtype: float64

# %%
category_revenue = df.groupby("Product_Category")["Purchase_Amount"].sum()

category_revenue.sort_values(ascending=False)
# Out:
# Product_Category
# Clothing       58407.27
# Electronics    57616.65
# Home           49482.66
# Beauty         47457.58
# Books          46087.96
# Name: Purchase_Amount, dtype: float64

# %%
age_spend = df.groupby("Age")["Purchase_Amount"].mean()

age_spend.head()
# Out:
# Age
# 18    242.992400
# 19    257.387083
# 20    238.137917
# 21    224.518421
# 22    331.813200
# Name: Purchase_Amount, dtype: float64

# %%
import matplotlib.pyplot as plt

age_spend.plot()

plt.title("Average Purchase Amount by Age")
plt.xlabel("Age")
plt.ylabel("Purchase Amount")

plt.show()

# %%
device_spend = df.groupby("Device_Type")["Purchase_Amount"].mean()

device_spend.plot(kind="bar")

plt.title("Average Purchase by Device Type")

plt.show()

# %%
return_analysis = df.groupby("Return")["Purchase_Amount"].mean()

return_analysis
# Out:
# Return
# 0    262.407598
# 1    255.866706
# Name: Purchase_Amount, dtype: float64

# %% [markdown]
# Platinum members are the highest spending customers.
#
# Certain product categories generate the majority of revenue.
#
# Discounts increase purchase value, suggesting promotional campaigns are effective.
#
# Customers with higher satisfaction scores tend to spend more.
